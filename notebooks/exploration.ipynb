# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##### Data loading

# %%
data = pd.read_excel('../data/raw/PCOS_data_without_infertility.xlsx', sheet_name='Full_new')

# %%
data.shape
# Out:
# (541, 45)

# %% [markdown]
# #### data exploration

# %%
data.head(5)
# Out:
#    Sl. No  Patient File No.  PCOS (Y/N)   Age (yrs)  Weight (Kg)  Height(Cm)   \
# 0       1                 1           0          28         44.6        152.0
# 1       2                 2           0          36         65.0        161.5
# 2       3                 3           1          33         68.8        165.0
# 3       4                 4           0          37         65.0        148.0
# 4       5                 5           0          25         52.0        161.0
#
#          BMI  Blood Group  Pulse rate(bpm)   RR (breaths/min)  ...  \
# 0  19.300000           15                78                22  ...
# 1  24.921163           15                74                20  ...
# 2  25.270891           11                72                18  ...
# 3  29.674945           13                72                20  ...
# 4  20.060954           11                72                18  ...
#
#    Fast food (Y/N)  Reg.Exercise(Y/N)  BP _Systolic (mmHg)  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 45 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Sl. No                  541 non-null    int64
#  1   Patient File No.        541 non-null    int64
#  2   PCOS (Y/N)              541 non-null    int64
#  3    Age (yrs)              541 non-null    int64
#  4   Weight (Kg)             541 non-null    float64
#  5   Height(Cm)              541 non-null    float64
#  6   BMI                     541 non-null    float64
#  7   Blood Group             541 non-null    int64
#  8   Pulse rate(bpm)         541 non-null    int64
#  9   RR (breaths/min)        541 non-null    int64
#  10  Hb(g/dl)                541 non-null    float64
#  11  Cycle(R/I)              541 non-null    int64
#  12  Cycle length(days)      541 non-null    int64
#  13  Marraige Status (Yrs)   540 non-null    float64
# ...

# %%
data.columns = data.columns.str.strip()

# %%
data.describe()
# Out:
#            Sl. No  Patient File No.  PCOS (Y/N)   Age (yrs)  Weight (Kg)  \
# count  541.000000        541.000000  541.000000  541.000000   541.000000
# mean   271.000000        271.000000    0.327172   31.430684    59.637153
# std    156.317519        156.317519    0.469615    5.411006    11.028287
# min      1.000000          1.000000    0.000000   20.000000    31.000000
# 25%    136.000000        136.000000    0.000000   28.000000    52.000000
# 50%    271.000000        271.000000    0.000000   31.000000    59.000000
# 75%    406.000000        406.000000    1.000000   35.000000    65.000000
# max    541.000000        541.000000    1.000000   48.000000   108.000000
#
#        Height(Cm)         BMI  Blood Group  Pulse rate(bpm)  RR (breaths/min)  \
# count  541.000000  541.000000   541.000000       541.000000        541.000000
# mean   156.484835   24.311285    13.802218        73.247689         19.243993
# ...

# %%
data.isnull().sum()
# Out:
# Sl. No                      0
# Patient File No.            0
# PCOS (Y/N)                  0
# Age (yrs)                   0
# Weight (Kg)                 0
# Height(Cm)                  0
# BMI                         0
# Blood Group                 0
# Pulse rate(bpm)             0
# RR (breaths/min)            0
# Hb(g/dl)                    0
# Cycle(R/I)                  0
# Cycle length(days)          0
# Marraige Status (Yrs)       1
# Pregnant(Y/N)               0
# No. of aborptions           0
# I   beta-HCG(mIU/mL)        0
# II    beta-HCG(mIU/mL)      0
# FSH(mIU/mL)                 0
# LH(mIU/mL)                  0
# FSH/LH                      0
# Hip(inch)                   0
# Waist(inch)                 0
# Waist:Hip Ratio             0
# TSH (mIU/L)                 0
# AMH(ng/mL)                  0
# PRL(ng/mL)                  0
# Vit D3 (ng/mL)              0
# PRG(ng/mL)                  0
# RBS(mg/dl)                  0
# Weight gain(Y/N)            0
# ...

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
categorical_columns = data.select_dtypes(include=['object','bool']).columns
print("categorical: ", categorical_columns)
# Out:
# categorical:  Index(['II    beta-HCG(mIU/mL)', 'AMH(ng/mL)', 'Unnamed: 44'], dtype='object')

# %%
data['AMH(ng/mL)']
# Out:
# 0      2.07
# 1      1.53
# 2      6.63
# 3      1.22
# 4      2.26
#        ...
# 536     1.7
# 537     5.6
# 538     3.7
# 539     5.2
# 540      20
# Name: AMH(ng/mL), Length: 541, dtype: object

# %%
data['II    beta-HCG(mIU/mL)']
#des valeurs extrêmes ont été identifiées dans cette colonne
# Out:
# 0        1.99
# 1        1.99
# 2      494.08
# 3        1.99
# 4      801.45
#         ...
# 536      1.99
# 537      1.99
# 538      1.99
# 539      1.99
# 540      1.99
# Name: II    beta-HCG(mIU/mL), Length: 541, dtype: object

# %%
data["II    beta-HCG(mIU/mL)"].value_counts()
# Out:
# II    beta-HCG(mIU/mL)
# 1.99      307
# 2.00        8
# 15.00       6
# 12.00       6
# 20.00       3
#          ...
# 168.99      1
# 237.50      1
# 10.24       1
# 104.87      1
# 5.81        1
# Name: count, Length: 203, dtype: int64

# %%
data['Weight (Kg)'].value_counts()
# Out:
# Weight (Kg)
# 60.0    36
# 50.0    34
# 52.0    27
# 65.0    25
# 56.0    22
#         ..
# 44.8     1
# 49.1     1
# 52.9     1
# 54.3     1
# 63.2     1
# Name: count, Length: 117, dtype: int64

# %%
data['Avg. F size (L) (mm)'].value_counts()
# Out:
# Avg. F size (L) (mm)
# 15.0    76
# 18.0    69
# 14.0    60
# 16.0    52
# 19.0    48
# 17.0    47
# 13.0    38
# 12.0    31
# 10.0    28
# 11.0    26
# 20.0    21
# 0.0      7
# 21.0     7
# 8.0      5
# 9.5      3
# 17.5     3
# 22.0     2
# 9.0      2
# 10.5     2
# 18.5     2
# 7.0      2
# 6.5      1
# 14.5     1
# 15.5     1
# 5.0      1
# 11.5     1
# 7.5      1
# 2.0      1
# 12.5     1
# 24.0     1
# 6.8      1
# Name: count, dtype: int64

# %%
data['Blood Group'].value_counts()
#11 samples of A+
#12 samples of A-
#13 samples of B+
#14 samples of B-
#15 samples of O+
#16 samples of O-
#17 samples of AB+
#18 samples of AB-
# Out:
# Blood Group
# 15    206
# 13    135
# 11    108
# 17     42
# 16     19
# 14     16
# 12     13
# 18      2
# Name: count, dtype: int64

# %%
data["PCOS (Y/N)"].value_counts()
# Out:
# PCOS (Y/N)
# 0    364
# 1    177
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="PCOS (Y/N)", data=data, palette="Set2")
plt.title("PCOS Diagnosis Count")
plt.xlabel("PCOS (0 = No, 1 = Yes)")
plt.ylabel("Count")
plt.show()
# Out:
# C:\Users\lando\AppData\Local\Temp\ipykernel_5948\189300121.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="PCOS (Y/N)", data=data, palette="Set2")

# %%
columns_to_plot = [
    'Follicle No. (R)', 'Follicle No. (L)', 
     'Weight (Kg)', 'BMI', 'Waist(inch)',
    'Hip(inch)', 'Avg. F size (L) (mm)', 'Endometrium (mm)', 'Avg. F size (R) (mm)', 'Pulse rate(bpm)',
    'Hb(g/dl)', 'Vit D3 (ng/mL)',  'AMH(ng/mL)',  'LH(mIU/mL)', 'RBS(mg/dl)',
    'No. of aborptions',"II    beta-HCG(mIU/mL)","AMH(ng/mL)"
]

for i, col in enumerate(columns_to_plot, 1):
    plt.figure(figsize=(12, 6))
    plt.subplot(len(columns_to_plot)//4 + 1, 4, i)
    numeric_data = pd.to_numeric(data[col], errors='coerce')
    sns.boxplot(x=numeric_data)
    plt.title(f'Boxplot of {col}')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Relationships between features

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Blood Group",data=data, hue='PCOS (Y/N)', palette="Set2")
plt.title("Blood Group Count")
plt.xlabel("Blood Group")
plt.ylabel("Count")
plt.show()
#11 samples of A+
#12 samples of A-
#13 samples of B+
#14 samples of B-
#15 samples of O+
#16 samples of O-
#17 samples of AB+
#18 samples of AB-

# %%
data['Skin darkening (Y/N)'].unique()
plt.figure(figsize=(6,4))
sns.countplot(x="Skin darkening (Y/N)",data=data, hue='PCOS (Y/N)', palette="Set2")
plt.title("Skin darkening Count")
plt.xlabel("Skin darkening")
plt.ylabel("Count")
plt.show()

# %%
data['Weight gain(Y/N)'].unique()
plt.figure(figsize=(6,4))
sns.countplot(x="Weight gain(Y/N)",data=data, hue='PCOS (Y/N)', palette="Set2")
plt.title("Weight gain Count")
plt.xlabel("Weight gain")
plt.ylabel("Count")
plt.show()

# %%
fig= sns.lmplot(data =data,x="Age (yrs)",y="BMI", hue="PCOS (Y/N)", palette= "coolwarm")
plt.show(fig)

#older women with higher BMI are more likely to have PCOS

# %%
sns.lmplot(data =data,x='Follicle No. (R)',y='Follicle No. (L)', hue="PCOS (Y/N)",palette="coolwarm")
plt.show()
#PCOS patients have more follicles in both ovaries

# %%
data['Cycle(R/I)'].unique()
# Out:
# array([2, 4, 5])

# %%
sns.lmplot(data =data,x="Age (yrs)",y="Cycle(R/I)", hue="PCOS (Y/N)",palette="coolwarm")
plt.show()
#PCOS patients have irregular cycles

# %%
sns.countplot(data=data, x="Cycle(R/I)", hue="PCOS (Y/N)", palette="coolwarm")
plt.title("Cycle Regularity Distribution by PCOS Status")
plt.xlabel("Cycle Regularity (Encoded)")
plt.ylabel("Count")
plt.show()
